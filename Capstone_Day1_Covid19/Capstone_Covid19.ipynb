# %%
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.callbacks import TensorBoard
import os
import datetime 
import IPython
import IPython.display
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np
import tensorflow as tf


mpl.rcParams['figure.figsize'] = (8,6)
mpl.rcParams['axes.grid'] = False

# %%
csv_path = r"C:\Users\zahiz\Desktop\Capstone_Day1_Covid19\cases_malaysia.csv"

df = pd.read_csv(csv_path,index_col='date', parse_dates=['date'])
df.head()
# Out:
#             cases_new  cases_import  cases_recovered  cases_active  \
# date
# 2020-01-25          4             4                0             4
# 2020-01-26          0             0                0             4
# 2020-01-27          0             0                0             4
# 2020-01-28          0             0                0             4
# 2020-01-29          3             3                0             7
#
#             cases_cluster  cases_unvax  cases_pvax  cases_fvax  cases_boost  \
# date
# 2020-01-25              0            4           0           0            0
# 2020-01-26              0            0           0           0            0
# 2020-01-27              0            0           0           0            0
# 2020-01-28              0            0           0           0            0
# 2020-01-29              0            3           0           0            0
#
#             cases_child  ...  cases_60_69  cases_70_79  cases_80  \
# date                     ...
# 2020-01-25            0  ...            0            0         0
# 2020-01-26            0  ...            0            0         0
# 2020-01-27            0  ...            0            0         0
# 2020-01-28            0  ...            0            0         0
# 2020-01-29            1  ...            0            0         0
#
#             cluster_import  cluster_religious  cluster_community  \
# date
# 2020-01-25             NaN                NaN                NaN
# 2020-01-26             NaN                NaN                NaN
# 2020-01-27             NaN                NaN                NaN
# 2020-01-28             NaN                NaN                NaN
# 2020-01-29             NaN                NaN                NaN
#
#             cluster_highRisk  cluster_education  cluster_detentionCentre  \
# date
# 2020-01-25               NaN                NaN                      NaN
# 2020-01-26               NaN                NaN                      NaN
# 2020-01-27               NaN                NaN                      NaN
# 2020-01-28               NaN                NaN                      NaN
# 2020-01-29               NaN                NaN                      NaN
#
#             cluster_workplace
# date
# 2020-01-25                NaN
# 2020-01-26                NaN
# 2020-01-27                NaN
# 2020-01-28                NaN
# 2020-01-29                NaN
#
# [5 rows x 30 columns]

# %%
df.describe().transpose()
# Out:
#                           count          mean           std  min      25%  \
# cases_new                1744.0   3050.001720   5588.837322  0.0   128.75
# cases_import             1744.0     22.502867     76.601202  0.0     1.00
# cases_recovered          1744.0   3023.658257   5540.421141  0.0   117.75
# cases_active             1744.0  37942.768922  61800.088695  1.0  8460.25
# cases_cluster            1744.0    306.498280    619.205875  0.0     0.00
# cases_unvax              1744.0   1172.648509   2339.900620  0.0    24.00
# cases_pvax               1744.0    250.495413    997.565343  0.0     0.00
# cases_fvax               1744.0    813.951261   1935.319149  0.0     1.00
# cases_boost              1744.0    812.906537   2248.538349  0.0     0.00
# cases_child              1744.0    371.459289    772.875075  0.0     8.75
# cases_adolescent         1744.0    189.412271    371.093242  0.0     5.00
# cases_adult              1744.0   2149.451835   3915.749958  0.0    93.75
# cases_elderly            1744.0    290.920872    496.374130  0.0    20.00
# cases_0_4                1744.0    150.692661    319.239412  0.0     3.00
# cases_5_11               1744.0    220.766628    457.346017  0.0     5.00
# cases_12_17              1744.0    189.412271    371.093242  0.0     5.00
# cases_18_29              1744.0    789.663417   1469.890617  0.0    29.00
# cases_30_39              1744.0    683.807913   1228.023117  0.0    31.00
# cases_40_49              1744.0    407.988532    736.685085  0.0    19.00
# cases_50_59              1744.0    267.991972    490.366601  0.0    10.00
# cases_60_69              1744.0    171.413991    311.671526  0.0     6.00
# cases_70_79              1744.0     78.603211    136.296569  0.0     4.00
# cases_80                 1744.0     40.902523     55.342761  0.0     6.00
# cluster_import           1174.0      0.252981      2.273661  0.0     0.00
# cluster_religious        1174.0      7.410562     33.259912  0.0     0.00
# cluster_community        1174.0     62.598807    140.302383  0.0     0.00
# cluster_highRisk         1174.0     11.992334     23.103513  0.0     0.00
# cluster_education        1174.0     36.117547     90.481170  0.0     0.00
# cluster_detentionCentre  1174.0     20.367121     51.370516  0.0     0.00
# cluster_workplace        1174.0    201.829642    398.870654  0.0     0.00
#
#                              50%       75%       max
# cases_new                  803.0   3200.00   33406.0
# cases_import                 3.0      8.00     719.0
# cases_recovered            796.5   3227.50   33872.0
# cases_active             13839.0  36568.00  323791.0
# cases_cluster                7.0    269.25    3394.0
# cases_unvax                125.0   1162.75   12681.0
# cases_pvax                   2.0     19.00    7315.0
# cases_fvax                  44.0    439.00   13058.0
# cases_boost                 83.0    496.25   18176.0
# cases_child                 48.0    245.25    4389.0
# cases_adolescent            36.0    168.00    2177.0
# cases_adult                588.5   2303.00   24815.0
# cases_elderly               77.0    335.25    3348.0
# cases_0_4                   18.0    102.00    1966.0
# cases_5_11                  29.0    142.00    2794.0
# cases_12_17                 36.0    168.00    2177.0
# cases_18_29                196.5    833.25    9184.0
# cases_30_39                199.5    744.50    8120.0
# cases_40_49                114.0    433.25    4610.0
# cases_50_59                 64.0    275.25    3082.0
# cases_60_69                 39.0    172.75    2060.0
# cases_70_79                 20.0     91.00     927.0
# cases_80                    19.0     54.25     361.0
# cluster_import               0.0      0.00      54.0
# cluster_religious            0.0      0.00     359.0
# cluster_community            0.0     34.75     825.0
# cluster_highRisk             1.0     13.00     189.0
# cluster_education            2.0     25.00     920.0
# cluster_detentionCentre      0.0      6.00     439.0
# cluster_workplace            0.0    155.75    2338.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1744 entries, 2020-01-25 to 2024-11-02
# Data columns (total 30 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   cases_new                1744 non-null   int64
#  1   cases_import             1744 non-null   int64
#  2   cases_recovered          1744 non-null   int64
#  3   cases_active             1744 non-null   int64
#  4   cases_cluster            1744 non-null   int64
#  5   cases_unvax              1744 non-null   int64
#  6   cases_pvax               1744 non-null   int64
#  7   cases_fvax               1744 non-null   int64
#  8   cases_boost              1744 non-null   int64
#  9   cases_child              1744 non-null   int64
#  10  cases_adolescent         1744 non-null   int64
#  11  cases_adult              1744 non-null   int64
#  12  cases_elderly            1744 non-null   int64
#  13  cases_0_4                1744 non-null   int64
#  14  cases_5_11               1744 non-null   int64
#  15  cases_12_17              1744 non-null   int64
#  16  cases_18_29              1744 non-null   int64
#  17  cases_30_39              1744 non-null   int64
#  18  cases_40_49              1744 non-null   int64
#  19  cases_50_59              1744 non-null   int64
#  20  cases_60_69              1744 non-null   int64
#  21  cases_70_79              1744 non-null   int64
#  22  cases_80                 1744 non-null   int64
#  23  cluster_import           1174 non-null   float64
#  24  cluster_religious        1174 non-null   float64
#  25  cluster_community        1174 non-null   float64
#  26  cluster_highRisk         1174 non-null   float64
#  27  cluster_education        1174 non-null   float64
#  28  cluster_detentionCentre  1174 non-null   float64
#  29  cluster_workplace        1174 non-null   float64
# dtypes: float64(7), int64(23)
# memory usage: 422.4 KB

# %%
df.isna().sum()
# Out:
# cases_new                    0
# cases_import                 0
# cases_recovered              0
# cases_active                 0
# cases_cluster                0
# cases_unvax                  0
# cases_pvax                   0
# cases_fvax                   0
# cases_boost                  0
# cases_child                  0
# cases_adolescent             0
# cases_adult                  0
# cases_elderly                0
# cases_0_4                    0
# cases_5_11                   0
# cases_12_17                  0
# cases_18_29                  0
# cases_30_39                  0
# cases_40_49                  0
# cases_50_59                  0
# cases_60_69                  0
# cases_70_79                  0
# cases_80                     0
# cluster_import             570
# cluster_religious          570
# cluster_community          570
# cluster_highRisk           570
# cluster_education          570
# cluster_detentionCentre    570
# cluster_workplace          570
# dtype: int64

# %%
columns_to_fill = [
    'cluster_import', 'cluster_religious', 'cluster_highRisk', 
    'cluster_education', 'cluster_detentionCentre', 
    'cluster_workplace', 'cluster_community'
]

# Loop through each column and apply fillna(0)
for col in columns_to_fill:
    df[col] = df[col].fillna(0)

# %%
df.isna().sum()
# Out:
# cases_new                  0
# cases_import               0
# cases_recovered            0
# cases_active               0
# cases_cluster              0
# cases_unvax                0
# cases_pvax                 0
# cases_fvax                 0
# cases_boost                0
# cases_child                0
# cases_adolescent           0
# cases_adult                0
# cases_elderly              0
# cases_0_4                  0
# cases_5_11                 0
# cases_12_17                0
# cases_18_29                0
# cases_30_39                0
# cases_40_49                0
# cases_50_59                0
# cases_60_69                0
# cases_70_79                0
# cases_80                   0
# cluster_import             0
# cluster_religious          0
# cluster_community          0
# cluster_highRisk           0
# cluster_education          0
# cluster_detentionCentre    0
# cluster_workplace          0
# dtype: int64

# %%
# df['date'] = pd.to_datetime(df['date'])

# %%
df.head()
# Out:
#             cases_new  cases_import  cases_recovered  cases_active  \
# date
# 2020-01-25          4             4                0             4
# 2020-01-26          0             0                0             4
# 2020-01-27          0             0                0             4
# 2020-01-28          0             0                0             4
# 2020-01-29          3             3                0             7
#
#             cases_cluster  cases_unvax  cases_pvax  cases_fvax  cases_boost  \
# date
# 2020-01-25              0            4           0           0            0
# 2020-01-26              0            0           0           0            0
# 2020-01-27              0            0           0           0            0
# 2020-01-28              0            0           0           0            0
# 2020-01-29              0            3           0           0            0
#
#             cases_child  ...  cases_60_69  cases_70_79  cases_80  \
# date                     ...
# 2020-01-25            0  ...            0            0         0
# 2020-01-26            0  ...            0            0         0
# 2020-01-27            0  ...            0            0         0
# 2020-01-28            0  ...            0            0         0
# 2020-01-29            1  ...            0            0         0
#
#             cluster_import  cluster_religious  cluster_community  \
# date
# 2020-01-25             0.0                0.0                0.0
# 2020-01-26             0.0                0.0                0.0
# 2020-01-27             0.0                0.0                0.0
# 2020-01-28             0.0                0.0                0.0
# 2020-01-29             0.0                0.0                0.0
#
#             cluster_highRisk  cluster_education  cluster_detentionCentre  \
# date
# 2020-01-25               0.0                0.0                      0.0
# 2020-01-26               0.0                0.0                      0.0
# 2020-01-27               0.0                0.0                      0.0
# 2020-01-28               0.0                0.0                      0.0
# 2020-01-29               0.0                0.0                      0.0
#
#             cluster_workplace
# date
# 2020-01-25                0.0
# 2020-01-26                0.0
# 2020-01-27                0.0
# 2020-01-28                0.0
# 2020-01-29                0.0
#
# [5 rows x 30 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1744 entries, 2020-01-25 to 2024-11-02
# Data columns (total 30 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   cases_new                1744 non-null   int64
#  1   cases_import             1744 non-null   int64
#  2   cases_recovered          1744 non-null   int64
#  3   cases_active             1744 non-null   int64
#  4   cases_cluster            1744 non-null   int64
#  5   cases_unvax              1744 non-null   int64
#  6   cases_pvax               1744 non-null   int64
#  7   cases_fvax               1744 non-null   int64
#  8   cases_boost              1744 non-null   int64
#  9   cases_child              1744 non-null   int64
#  10  cases_adolescent         1744 non-null   int64
#  11  cases_adult              1744 non-null   int64
#  12  cases_elderly            1744 non-null   int64
#  13  cases_0_4                1744 non-null   int64
#  14  cases_5_11               1744 non-null   int64
#  15  cases_12_17              1744 non-null   int64
#  16  cases_18_29              1744 non-null   int64
#  17  cases_30_39              1744 non-null   int64
#  18  cases_40_49              1744 non-null   int64
#  19  cases_50_59              1744 non-null   int64
#  20  cases_60_69              1744 non-null   int64
#  21  cases_70_79              1744 non-null   int64
#  22  cases_80                 1744 non-null   int64
#  23  cluster_import           1744 non-null   float64
#  24  cluster_religious        1744 non-null   float64
#  25  cluster_community        1744 non-null   float64
#  26  cluster_highRisk         1744 non-null   float64
#  27  cluster_education        1744 non-null   float64
#  28  cluster_detentionCentre  1744 non-null   float64
#  29  cluster_workplace        1744 non-null   float64
# dtypes: float64(7), int64(23)
# memory usage: 422.4 KB

# %%
# df['cases_new'] = pd.to_numeric(df['cases_new'], errors='coerce')

# %%
tstart = 2020
tend = 2022

def train_test_plot(df,tstart,tend):
    df.loc[f'{tstart}':f'{tend}','cases_new'].plot(figsize=(16,4),label=f"Train (Before {tend+1})")
    df.loc[f'{tend+1}':, 'cases_new'].plot(figsize=(16,4),label=f"Test ({tend+1} and beyond)")
    plt.legend()
    plt.title('Covid 19')
    plt.show()

train_test_plot(df,tstart,tend)

# %%
def train_test_split(df,tstart,tend):
    train = df.loc[f"{tstart}":f"{tend}","cases_new"].values
    test = df.loc[f"{tend+1}":,"cases_new"].values
    return train,test

training_set,test_set = train_test_split(df,tstart,tend)

# %%
sc = MinMaxScaler(feature_range=(0,1))
training_set = training_set.reshape(-1,1)
training_set_scaled = sc.fit_transform(training_set)
# print(type(training_set_scaled))
# print(training_set_scaled.shape)
print(training_set_scaled[:5])
# Out:
# [[1.19738969e-04]
#  [0.00000000e+00]
#  [0.00000000e+00]
#  [0.00000000e+00]
#  [8.98042268e-05]]

# %%
arr = np.array([1,2,3,4,5,6])
print(arr.shape)

print(arr.reshape(3,-1).shape)
# Out:
# (6,)
# (3, 2)

# %%
def split_sequence(sequence,n_steps):
    X,y = list(),list()
    for i in range(len(sequence)):
        end_ix = i + n_steps
        if end_ix > len(sequence) - 1:
            break
        seq_x,seq_y = sequence[i:end_ix],sequence[end_ix]
        X.append(seq_x)
        y.append(seq_y)
    return np.array(X),np.array(y)

n_steps = 60
features = 1
# split into samples
X_train,y_train = split_sequence(training_set_scaled,n_steps)

# %%
# Reshape X_train for model
X_train = X_train.reshape(X_train.shape[0],X_train.shape[1],features)
print(X_train.shape)
# Out:
# (1012, 60, 1)

# %%
# The LSTM Architecture
model_lstm = Sequential()
model_lstm.add(LSTM(units=32,activation='tanh',input_shape=(n_steps,features),return_sequences=True))
model_lstm.add(Dropout(0.2))
model_lstm.add(LSTM(units=64))
model_lstm.add(Dense(units=1))
# Compiling the model
model_lstm.compile(optimizer='adam',loss='mse', metrics=['mae'])

print(model_lstm.summary())
# Out:
# c:\Users\zahiz\anaconda\envs\ypai09\lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_2 (LSTM)                   │ (None, 60, 32)         │         4,352 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 60, 32)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_3 (LSTM)                   │ (None, 64)             │        24,832 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 29,249 (114.25 KB)
#  Trainable params: 29,249 (114.25 KB)
#  Non-trainable params: 0 (0.00 B)
# None

# %%
logpath = "tensorboard/ts_single" + datetime.datetime.now().strftime("%Y-%m-%d_%H%M%S")
tb = keras.callbacks.TensorBoard(logpath)

# %%
model_lstm.fit(X_train,y_train,epochs = 50,batch_size=32, callbacks=([tb]))
# Out:
# Epoch 1/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 0.0309 - mae: 0.0985
# Epoch 2/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0045 - mae: 0.0361
# Epoch 3/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0023 - mae: 0.0257
# Epoch 4/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0018 - mae: 0.0228
# Epoch 5/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0016 - mae: 0.0231
# Epoch 6/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0017 - mae: 0.0238
# Epoch 7/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0020 - mae: 0.0255
# Epoch 8/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0018 - mae: 0.0243
# Epoch 9/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0014 - mae: 0.0210
# Epoch 10/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0019 - mae: 0.0237
# Epoch 11/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0014 - mae: 0.0219
# Epoch 12/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0014 - mae: 0.0223
# Epoch 13/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0016 - mae: 0.0248
# Epoch 14/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0016 - mae: 0.0235
# Epoch 15/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0014 - mae: 0.0220
# Epoch 16/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0016 - mae: 0.0235
# Epoch 17/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0018 - mae: 0.0238
# Epoch 18/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0016 - mae: 0.0229
# Epoch 19/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0013 - mae: 0.0213
# Epoch 20/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0014 - mae: 0.0217
# Epoch 21/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0014 - mae: 0.0233
# Epoch 22/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0017 - mae: 0.0237
# Epoch 23/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0018 - mae: 0.0242
# Epoch 24/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0014 - mae: 0.0224
# Epoch 25/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0017 - mae: 0.0236
# Epoch 26/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0016 - mae: 0.0252
# Epoch 27/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0015 - mae: 0.0242
# Epoch 28/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0011 - mae: 0.0202
# Epoch 29/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0016 - mae: 0.0226
# Epoch 30/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0014 - mae: 0.0235
# Epoch 31/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0015 - mae: 0.0224
# Epoch 32/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0015 - mae: 0.0234
# Epoch 33/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0014 - mae: 0.0216
# Epoch 34/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0012 - mae: 0.0208
# Epoch 35/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0016 - mae: 0.0233
# Epoch 36/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0014 - mae: 0.0214
# Epoch 37/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0015 - mae: 0.0223
# Epoch 38/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0011 - mae: 0.0201
# Epoch 39/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0014 - mae: 0.0223
# Epoch 40/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0014 - mae: 0.0223
# Epoch 41/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0015 - mae: 0.0236
# Epoch 42/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0015 - mae: 0.0226
# Epoch 43/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0014 - mae: 0.0222
# Epoch 44/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0012 - mae: 0.0210
# Epoch 45/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0014 - mae: 0.0222
# Epoch 46/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0013 - mae: 0.0201
# Epoch 47/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0011 - mae: 0.0193
# Epoch 48/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0015 - mae: 0.0230
# Epoch 49/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0012 - mae: 0.0198
# Epoch 50/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0015 - mae: 0.0224

# %%
dataset_total = df.loc[:,'cases_new']
inputs = dataset_total[len(dataset_total) - len(test_set) - n_steps :].values
inputs = inputs.reshape(-1,1)
# scaling
inputs = sc.transform(inputs)

# Split into samples
X_test,y_test = split_sequence(inputs,n_steps)
# reshape
X_test = X_test.reshape(X_test.shape[0],X_test.shape[1],features)
# predictions
predicted_covid = model_lstm.predict(X_test)
# inverse transform the values - undo the normalization of stock prices (undo any sklearn's transform)
predicted_covid = sc.inverse_transform(predicted_covid)
# Out:
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step

# %%
def plot_predictions(test,predicted):
    plt.plot(test,color='gray',label='Real')
    plt.plot(predicted,color='red',label='Predicted')
    plt.title('Covid19 Prediction')
    plt.xlabel('Time')
    plt.ylabel('Covid19 Cases')
    plt.legend()
    plt.show()

def return_rmse(test,predicted):
    rmse = np.sqrt(mean_squared_error(test,predicted))
    print('The root mean square error is {:.2f}.'.format(rmse))

# %%
plot_predictions(test_set,predicted_covid)

# %%
evaluation = model_lstm.evaluate(X_test,y_test)
print(evaluation)
# Out:
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.7772e-05 - mae: 0.0049
# [5.649004742735997e-05, 0.0052059912122786045]

# %%
mae = evaluation[1]
print(f"mae \n: {mae}")
# Out:
# mae
# : 0.0052059912122786045

# %%
mape = mae/sum(abs(y_test)) * 100
print(mape)
# Out:
# [0.05945158]
